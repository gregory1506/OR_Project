# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors
# %matplotlib inline

# %%
edges = []
with open("data.txt","r") as f:
    for line in f:
        edges.append(line.split())
G = nx.from_edgelist(edges)
for node in G:
    G.nodes[node]['prob'] = 0.25
    G.nodes[node]['clicked'] = False
len(G['Pat'])
# Out:
# 4

# %%
plt.figure(1, figsize=(10, 10))
plt.subplot(121)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","violet","blue"])
val_map = {'Joe': 1}
values = [val_map.get(node, -1) for node in G.nodes()]
nx.draw(G, with_labels=True, cmap=cmap, node_color = values, font_weight='bold', node_size=2000)

# %%
def scaleNodeProb(G):
    alpha = 0.15
    for node in G:
        n = 0
        for x in G.neighbors(node):
            if G.nodes[x]['clicked'] == True:
                n += 1
        f = len(G[node])
        G.nodes[node]['prob'] += max(0,min(1,(0.25+alpha*n/f)))

# %%
import itertools
l = [1,2,3,4,5,6,7]
print(list(itertools.combinations(l, 3)))
# Out:
# [(1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 2, 6), (1, 2, 7), (1, 3, 4), (1, 3, 5), (1, 3, 6), (1, 3, 7), (1, 4, 5), (1, 4, 6), (1, 4, 7), (1, 5, 6), (1, 5, 7), (1, 6, 7), (2, 3, 4), (2, 3, 5), (2, 3, 6), (2, 3, 7), (2, 4, 5), (2, 4, 6), (2, 4, 7), (2, 5, 6), (2, 5, 7), (2, 6, 7), (3, 4, 5), (3, 4, 6), (3, 4, 7), (3, 5, 6), (3, 5, 7), (3, 6, 7), (4, 5, 6), (4, 5, 7), (4, 6, 7), (5, 6, 7)]

# %%
impressions = [(5,0),(4,1),(3,2),(2,3),(1,4),(0,5)]
